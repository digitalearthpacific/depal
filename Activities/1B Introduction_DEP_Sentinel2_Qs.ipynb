# %% [markdown]
# <div><img src="https://github.com/digitalearthpacific/DigitalEarthPacific/blob/main/notebooks/DEP_LCAST/reference_materials/images/1B/1.a.png?raw=true" width="800"/></div>

# %% [markdown]
# # Activity Notebook 1B) Introduction to Python in Digital Earth Pacific (DEP)
# Intended for users of Python who have recently completed **'Activity Notebook 1A'** which provides the foundations of Python for users intending to move onto this notebook: **'Activity Notebook 1B'** introductions to [Digital Earth Pacific (DEP)](https://github.com/digitalearthpacific/DigitalEarthPacific/tree/main). We will again be working with Python within a Jupyter Notebook environment as the IDE. For questions regarding this notebook contact the author via https://github.com/nicholasmetherall

# %% [markdown]
# ### Digital Earth Pacific (DEP) Notebook

# %% [markdown]
# Follow the example of code below to set up your Digital Earth Pacific (DEP) environment.

# %%
import sys
sys.path.insert(0, '..')
import depal as dep
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# For larger areas of interest or more computionally task, replace the `dep.init()` below with `dep.init('remote')`.
#
# To change default resolution of output products use `dep.init('remote', resolution=10)`

# %%
dep.init()
# Out:
# Initiating DEPAL...
# <Client: 'tcp://127.0.0.1:36201' processes=4 threads=8, memory=32.00 GiB>
# /user/nicholasm@spc.int/proxy/8787/status

# %% [markdown]
# Your code goes in the cells below. Add more cells here by clicking on the + button above.
#
# First let's list out the countries covered within Digital Earth Pacific (DEP):
#
# > *dep.list_countries()
#
# - Where *dep.* is the module
# - *list_countries()* is the function that converts requests or simple operations into an object.
#
# By running this block of code you can process data. This particular function returns a list of data as a result.
#
# In this case, the function is to provide the list of countries covered within the DEP module.

# %%
dep.list_countries()
# Out:
#                            0
# 0             American Samoa
# 1               Cook Islands
# 2                       Fiji
# 3           French Polynesia
# 4                       Guam
# 5                   Kiribati
# 6           Marshall Islands
# 7                 Micronesia
# 8                      Nauru
# 9              New Caledonia
# 10                      Niue
# 11  Northern Mariana Islands
# 12                     Palau
# 13          Papua New Guinea
# 14          Pitcairn Islands
# 15                     Samoa
# 16           Solomon Islands
# 17                   Tokelau
# 18                     Tonga
# 19                    Tuvalu
# 20                   Vanuatu
# 21         Wallis and Futuna

# %% [markdown]
# The list you have generated above is an example of using a function to call on default values stored within a library.
#
# Now we will be working in Tonga so we should explore more about the kind of data stored for this country. In order to do this, we will next seek to list the boundary types.
#
# First type the module 'dep.' then type the function 'list_boundary_types' then within the brackets you can search for a particular subset of the total list. In this case, within the brackets we will search for the country parameter "Tonga"

# %%
dep.list_boundary_types("Tonga")
# Out:
#               0
# 0  Island Group
# 1      District

# %% [markdown]
# The list you have returned here shows that there are two geographic scales of analysis available for Tonga in DEP. These include the "island group" level and the "district" level.
#
# If you wish to delve into these two sub-groups within the stored values, you will need to call another list function. Within this list function you will need to pass the key words within the brackets as you did above but now you will need to list two key words in the order of the two parameters: First the country parameter and then the boundary type parameter i.e.
# >module.function("Country", "boundary type")
#
# Where :
# module = dep
# function = list_country_boundary
#
# parameters
# country = "Tonga"
# list = "Tonga"
#
# When calling these functions keep in mind the following:
#
# 1. The order of the arguments listed is important to make the function run properly.
# 2. There should be only one value for one parameter.
# 3. The passed keyword name should match with the actual keyword name.
#
# Now with this in mind, to better understand the boundary types let's first explore the island group level. Try the same list function but this time include two parameters "Tonga" and "Island Group". You will need to separate the two with a commma to pass this function.Try to get the list of Island groups by writing a function in the code cell block below:

# %%
dep.list_country_boundary("Tonga","Island Group")
# Out:
#            0
# 0       'Eua
# 1    Ha'apai
# 2      Niuas
# 3  Tongatapu
# 4     Vava'u

# %% [markdown]
# Now try to get a list of districts covered in DEP.

# %%
dep.list_country_boundary("Tonga","District")
# Out:
#                0
# 0           n.a.
# 1      Kolofo'ou
# 2     Kolomotu'a
# 3        Kolovai
# 4         Lapaha
# 5       Nukunuku
# 6  Tatakamotonga
# 7          Vaini

# %% [markdown]
# Let's now start showing some of the data from these lists of boundary types. In order to show the data using the **visualise()** function, we first have to access the datasets using a **get_** function.
#
# Let's start by accessing the country boundary of Tonga as an example. In order to do this we must first define a variable.
#
# In this example the variable we will define it as the boundary of Tonga or **boundary_tonga** since you cannot use spaces in Python code. In this case the variable will be defined as the function to get the country boundary.
#
# > dep.get_country_boundary("Tonga")
#
# Try to define this variable here:

# %%
boundary_tonga = dep.get_country_boundary("Tonga")

# %% [markdown]
# Now that you have accessed this data and downloaded this data you can now visualise this data in an interactive map as part of the leafmap functionality within Python notebooks. This function has been wrapped and simplified in DEP using the **explore()** function.
#
# Try to input your area of interest variable followed by .explore()

# %%
boundary_tonga.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d04064f8e2b1ab45b96edef38fc36fca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d04064f8e2b1ab45b96edef38fc36fca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d04064f8e2b1ab45b96edef38fc36fca = L.map(
#                 &quot;map_d04064f8e2b1ab45b96edef38fc36fca&quot;,
#                 {
#                     center: [-18.957760000499974, -174.97441899999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d04064f8e2b1ab45b96edef38fc36fca);
#
#
#
#
#
#             var tile_layer_a9f89f056c34491c7672143a5c9ed790 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d04064f8e2b1ab45b96edef38fc36fca);
#
#
#             map_d04064f8e2b1ab45b96edef38fc36fca.fitBounds(
#                 [[-22.34972400099997, -176.21383699999993], [-15.565795999999978, -173.73500099999998]],
#                 {}
#             );
#
#
#         function geo_json_176902241f81faec0b87dea0b2c81136_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_176902241f81faec0b87dea0b2c81136_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_176902241f81faec0b87dea0b2c81136_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_176902241f81faec0b87dea0b2c81136_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_176902241f81faec0b87dea0b2c81136_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_176902241f81faec0b87dea0b2c81136.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_176902241f81faec0b87dea0b2c81136_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_176902241f81faec0b87dea0b2c81136 = L.geoJson(null, {
#                 onEachFeature: geo_json_176902241f81faec0b87dea0b2c81136_onEachFeature,
#
#                 style: geo_json_176902241f81faec0b87dea0b2c81136_styler,
#                 pointToLayer: geo_json_176902241f81faec0b87dea0b2c81136_pointToLayer
#         });
#
#         function geo_json_176902241f81faec0b87dea0b2c81136_add (data) {
#             geo_json_176902241f81faec0b87dea0b2c81136
#                 .addData(data)
#                 .addTo(map_d04064f8e2b1ab45b96edef38fc36fca);
#         }
#             geo_json_176902241f81faec0b87dea0b2c81136_add({&quot;bbox&quot;: [-176.21383699999993, -22.34972400099997, -173.73500099999998, -15.565795999999978], &quot;features&quot;: [{&quot;bbox&quot;: [-176.21383699999993, -22.34972400099997, -173.73500099999998, -15.565795999999978], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-176.20329299899998, -22.33512900099987], [-176.20315599999992, -22.33512900099987], [-176.202286, -22.3353289989999], [-176.20199599899996, -22.335462999999947], [-176.20170599999994, -22.335462999999947], [-176.20106500099993, -22.335862999999847], [-176.20054599899998, -22.336063000999957], [-176.20019500099997, -22.33646399999992], [-176.19998200099994, -22.336728999999934], [-176.19969199999994, -22.336860999999885], [-176.19940199899992, -22.337129999999945], [-176.19897499999993, -22.337527998999917], [-176.19888299999997, -22.337778000999947], [-176.1980439989999, -22.33863999999994], [-176.1980439989999, -22.339309998999966], [-176.197754001, -22.33950999999996], [-176.197754001, -22.339642998999977], [-176.19738800099998, -22.339910998999926], [-176.19717399899994, -22.34017799999998], [-176.19694499999991, -22.340833999999916], [-176.19805899999992, -22.34194400099994

# %% [markdown]
# As you can see you have now generated an interactive map that you can **explore.** Scroll through the map to each of the island groups in Tonga and notice the boundaries have been highlighted because you have already used the **get_** function to access and download this data.
#
# Next repeat this workflow to see the boundary of Vava'u.
# 1. Define a new variable **boundary_vavau** with the **get_** function
# 2. Use the **explore()** function to generate an interactive map to visualise this data

# %%
boundary_vavau = dep.get_country_admin_boundary("Tonga", "Island Group", "Vava'u")

# %%
boundary_vavau.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fb6cf89730b661468873cb72c66baba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fb6cf89730b661468873cb72c66baba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fb6cf89730b661468873cb72c66baba = L.map(
#                 &quot;map_8fb6cf89730b661468873cb72c66baba&quot;,
#                 {
#                     center: [-17.37304700049998, -174.79112249999991],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8fb6cf89730b661468873cb72c66baba);
#
#
#
#
#
#             var tile_layer_669887a334524f8921c2e2406495fbbb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8fb6cf89730b661468873cb72c66baba);
#
#
#             map_8fb6cf89730b661468873cb72c66baba.fitBounds(
#                 [[-19.180298000999983, -175.68029799999994], [-15.565795999999978, -173.90194699999992]],
#                 {}
#             );
#
#
#         function geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea = L.geoJson(null, {
#                 onEachFeature: geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_onEachFeature,
#
#                 style: geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_styler,
#                 pointToLayer: geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_pointToLayer
#         });
#
#         function geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_add (data) {
#             geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea
#                 .addData(data)
#                 .addTo(map_8fb6cf89730b661468873cb72c66baba);
#         }
#             geo_json_d9f3fc898d18421e7ef2ff0c3dcff2ea_add({&quot;bbox&quot;: [-175.68029799999994, -19.180298000999983, -173.90194699999992, -15.565795999999978], &quot;features&quot;: [{&quot;bbox&quot;: [-175.68029799999994, -19.180298000999983, -173.90194699999992, -15.565795999999978], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-174.85051000099998, -19.178662998999982], [-174.85000599999992, -19.178054999999915], [-174.84986899899997, -19.178054999999915], [-174.849715999, -19.178054999999915], [-174.84944199899996, -19.177777999999932], [-174.84861799999993, -19.177777999999932], [-174.848053, -19.178332998999906], [-174.84808299999997, -19.178891999999905], [-174.84916699999997, -19.18000000099994], [-174.84930400099992, -19.18000000099994], [-174.84941099899999, -19.180059000999904], [-174.8497309999999, -19.18025999899993], [-174.84979199999998, -19.180298000999983], [-174.85000599999992, -19.180276999999933], [-174.85082999899998, -19.17944499899994], [-174.8507689989999, -19.179198999999983], [-174.85060100099994, -19.178863999999976], [-174.85051000099998, -19.178662998999982]]], [[[-174.0792079999999, -18.82002299999982], [-174.07977299999993, -18.820317999999872], [-174.0798489999999, -18.82

# %% [markdown]
# Now you can see Vava'u within the map .explore() visualisation above. You have practiced this workflow at the national level and the island group level. Next try this for the district level. In this example we would like you to show a map of the administrative boundary of Lapaha. Repeat the workflow above but this time using the parameter of "District". You may wish to define this variable using a clear explanatory name. For example **district_lapaha**

# %%
district_lapaha = dep.get_country_admin_boundary("Tonga", "District", "Lapaha")

# %%
district_lapaha.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47eff099db75054e8682e9ffc814df0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47eff099db75054e8682e9ffc814df0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47eff099db75054e8682e9ffc814df0c = L.map(
#                 &quot;map_47eff099db75054e8682e9ffc814df0c&quot;,
#                 {
#                     center: [-21.1239944914999, -175.05166649999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_47eff099db75054e8682e9ffc814df0c);
#
#
#
#
#
#             var tile_layer_2fef26f03a400ce1eb4db3e2528f12c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47eff099db75054e8682e9ffc814df0c);
#
#
#             map_47eff099db75054e8682e9ffc814df0c.fitBounds(
#                 [[-21.194933982999885, -175.12971499999998], [-21.053054999999915, -174.9736179999999]],
#                 {}
#             );
#
#
#         function geo_json_f32c02a1899b7358b7c0eb817b60b586_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f32c02a1899b7358b7c0eb817b60b586_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f32c02a1899b7358b7c0eb817b60b586_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f32c02a1899b7358b7c0eb817b60b586_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f32c02a1899b7358b7c0eb817b60b586_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_f32c02a1899b7358b7c0eb817b60b586.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f32c02a1899b7358b7c0eb817b60b586_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f32c02a1899b7358b7c0eb817b60b586 = L.geoJson(null, {
#                 onEachFeature: geo_json_f32c02a1899b7358b7c0eb817b60b586_onEachFeature,
#
#                 style: geo_json_f32c02a1899b7358b7c0eb817b60b586_styler,
#                 pointToLayer: geo_json_f32c02a1899b7358b7c0eb817b60b586_pointToLayer
#         });
#
#         function geo_json_f32c02a1899b7358b7c0eb817b60b586_add (data) {
#             geo_json_f32c02a1899b7358b7c0eb817b60b586
#                 .addData(data)
#                 .addTo(map_47eff099db75054e8682e9ffc814df0c);
#         }
#             geo_json_f32c02a1899b7358b7c0eb817b60b586_add({&quot;bbox&quot;: [-175.12971499999998, -21.194933982999885, -174.9736179999999, -21.053054999999915], &quot;features&quot;: [{&quot;bbox&quot;: [-175.12971499999998, -21.194933982999885, -174.9736179999999, -21.053054999999915], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-175.11842823999993, -21.185721034999915], [-175.12889099999992, -21.181390998999973], [-175.12693799999997, -21.181390998999973], [-175.12611399999992, -21.18135099999995], [-175.1254730009999, -21.181217000999936], [-175.1247559999999, -21.18088200099993], [-175.12425199999996, -21.18054799899994], [-175.12396199899993, -21.18028100099997], [-175.12333700099992, -21.17972199999997], [-175.1230620009999, -21.179444999999873], [-175.12277199999997, -21.179444999999873], [-175.12138399999998, -21.178054999999972], [-175.12138399999998, -21.177220999999975], [-175.12083400099993, -21.176664000999892], [-175.12083400099993, -21.17639000099996], [-175.12028500099998, -21.175832999999955], [-175.1199949999999, -21.175832999999955], [-175.11971999999997, -21.175553999999977], [-175.11971999999997, -21.17527800099998], [-175.11833199999995, -21.173889000999964], [-175.11805700099995, -21

# %% [markdown]
# Well done. You have visualised Lapaha. This will be one of the sites that we visit during the fieldtrip on Wednesday for the workshop.

# %% [markdown]
# Now that you have explored the default arguments, functions and parameters used for mapping out some of useful datasets in DEP, we will next explore the other datasets that are available through this platform. To learn more enter:
#
# > *dep.list_data_sources()*

# %%
dep.list_data_sources()
# Out:
#                                                           0  \
# 0                                 3dep-lidar-classification
# 1                                           3dep-lidar-copc
# 2                                            3dep-lidar-dsm
# 3                                            3dep-lidar-dtm
# 4                                     3dep-lidar-dtm-native
# 5                                            3dep-lidar-hag
# 6                                      3dep-lidar-intensity
# 7                                  3dep-lidar-pointsourceid
# 8                                        3dep-lidar-returns
# 9                                             3dep-seamless
# 10                                                 alos-dem
# 11                                          alos-fnf-mosaic
# 12                                       alos-palsar-mosaic
# 13                                                aster-l1t
# 14                                         chesapeake-lc-13
# 15                                          chesapeake-lc-7
# 16                                            chesapeake-lu
# 17                                          chloris-biomass
# 18                                         cil-gdpcir-cc-by
# 19                                      cil-gdpcir-cc-by-sa
# 20                                           cil-gdpcir-cc0
# 21                                           cop-dem-glo-30
# 22                                           cop-dem-glo-90
# 23                                         daymet-annual-hi
# 24                                         daymet-annual-na
# 25                                         daymet-annual-pr
# 26                                          daymet-daily-hi
# 27                                          daymet-daily-na
# 28                                          daymet-daily-pr
# 29                                        daymet-monthly-hi
# 30                                        daymet-monthly-na
# 31                                        daymet-monthly-pr
# 32                                          deltares-floods
# 33                              deltares-water-availability
# 34                                               drcog-lulc
# 35                                                  eclipse
# 36                                           ecmwf-forecast
# 37                                                 era5-pds
# 38                                               esa-cci-lc
# 39                                        esa-cci-lc-netcdf
# 40                                           esa-worldcover
# 41                                                      fia
# 42                                                  fws-nwi
# 43                                                      gap
# 44                                                     gbif
# 45                                          gnatsgo-rasters
# 46                                           gnatsgo-tables
# 47                                                 goes-cmi
# 48                                                 goes-glm
# 49                                            gpm-imerg-hhr
# 50                                                  gridmet
# 51                                                      hgb
# 52                                                     hrea
# 53                                          io-biodiversity
# 54                                                  io-lulc
# 55                                          io-lulc-9-class
# 56                                                  jrc-gsw
# 57                                       kaza-hydroforecast
# 58                                            landsat-c2-l1
# 59                                            landsat-c2-l2
# 60                                                     mobi
# 61                                           modis-09A1-061
# 62                                           modis-09Q1-061
# 63                                           modis-10A1-061
# 64                                           modis-10A2-061
# 65                                           modis-11A1-061
# 66                                           modis-11A2-061
# 67                                           modis-13A1-061
# 68                                           modis-13Q1-061
# 69                                           modis-14A1-061
# 70                                           modis-14A2-061
# 71                                          modis-15A2H-061
# 72                                          modis-15A3H-061
# 73                                         modis-16A3GF-061
# 74                                          modis-17A2H-061
# 75                                        modis-17A2HGF-061
# 76                                        modis-17A3HGF-061
# 77                                           modis-21A2-061
# 78                                           modis-43A4-061
# 79                                           modis-64A1-061
# 80                                             ms-buildings
# 81                                                     mtbs
# 82                                                     naip
# 83                                      nasa-nex-gddp-cmip6
# 84                                                  nasadem
# 85                                               noaa-c-cap
# 86                              noaa-cdr-ocean-heat-content
# 87                       noaa-cdr-ocean-heat-content-netcdf
# 88   noaa-cdr-sea-surface-temperature-optimum-interpolation
# 89                    noaa-cdr-sea-surface-temperature-whoi
# 90             noaa-cdr-sea-surface-temperature-whoi-netcdf
# 91                             noaa-climate-normals-gridded
# 92                              noaa-climate-normals-netcdf
# 93                             noaa-climate-normals-tabular
# 94                                   noaa-mrms-qpe-1h-pass1
# 95                                   noaa-mrms-qpe-1h-pass2
# 96                                  noaa-mrms-qpe-24h-pass2
# 97                                   noaa-nclimgrid-monthly
# 98                                          nrcan-landcover
# 99                                    planet-nicfi-analytic
# 100                                     planet-nicfi-visual
# 101                                          sentinel-1-grd
# 102                                          sentinel-1-rtc
# 103                                          sentinel-2-l2a
# 104                           sentinel-3-olci-lfr-l2-netcdf
# 105                           sentinel-3-olci-wfr-l2-netcdf
# 106                          sentinel-3-slstr-frp-l2-netcdf
# 107                          sentinel-3-slstr-lst-l2-netcdf
# 108                          sentinel-3-slstr-wst-l2-netcdf
# 109                           sentinel-3-sral-lan-l2-netcdf
# 110                           sentinel-3-sral-wat-l2-netcdf
# 111                        sentinel-3-synergy-aod-l2-netcdf
# 112                        sentinel-3-synergy-syn-l2-netcdf
# 113                        sentinel-3-synergy-v10-l2-netcdf
# 114                        sentinel-3-synergy-vg1-l2-netcdf
# 115                        sentinel-3-synergy-vgp-l2-netcdf
# 116                                   sentinel-5p-l2-netcdf
# 117                                            terraclimate
# 118                                               us-census
# 119                                                usda-cdl
# 120                                    usgs-lcmap-conus-v13
# 121                                   usgs-lcmap-hawaii-v10
#
#                                                                                  1
# 0                                                   USGS 3DEP Lidar Classification
# 1                                                      USGS 3DEP Lidar Point Cloud
# 2                                            USGS 3DEP Lidar Digital Surface Model
# 3                                            USGS 3DEP Lidar Digital Terrain Model
# 4                                   USGS 3DEP Lidar Digital Terrain Model (Native)
# 5                                              USGS 3DEP Lidar Height above Ground
# 6                                                        USGS 3DEP Lidar Intensity
# 7                                                     USGS 3DEP Lidar Point Source
# 8                                                          USGS 3DEP Lidar Returns
# 9                                                          USGS 3DEP Seamless DEMs
# 10                                                               ALOS World 3D-30m
# 11                                            ALOS Forest/Non-Forest Annual Mosaic
# 12                                                       ALOS PALSAR Annual Mosaic
# 13                                                                       ASTER L1T
# 14                                                Chesapeake Land Cover (13-class)
# 15                                                 Chesapeake Land Cover (7-class)
# 16                                                             Chesapeake Land Use
# 17                                                                 Chloris Biomass
# 18      CIL Global Downscaled Projections for Climate Impacts Research (CC-BY-4.0)
# 19   CIL Global Downscaled Projections for Climate Impacts Research (CC-BY-SA-4.0)
# 20        CIL Global Downscaled Projections for Climate Impacts Research (CC0-1.0)
# 21                                                           Copernicus DEM GLO-30
# 22                                                           Copernicus DEM GLO-90
# 23                                                            Daymet Annual Hawaii
# 24                                                     Daymet Annual North America
# 25                                                       Daymet Annual Puerto Rico
# 26                                                             Daymet Daily Hawaii
# 27                                                      Daymet Daily North America
# 28                                                        Daymet Daily Puerto Rico
# 29                                                           Daymet Monthly Hawaii
# 30                                                    Daymet Monthly North America
# 31                                                      Daymet Monthly Puerto Rico
# 32                                                      Deltares Global Flood Maps
# 33                                              Deltares Global Water Availability
# 34                      Denver Regional Council of Governments Land Use Land Cover
# 35                                            Urban Innovation Eclipse Sensor Data
# 36                                                     ECMWF Open Data (real-time)
# 37                                                                      ERA5 - PDS
# 38         ESA Climate Change Initiative Land Cover Maps (Cloud Optimized GeoTIFF)
# 39                          ESA Climate Change Initiative Land Cover Maps (NetCDF)
# 40                                                                  ESA WorldCover
# 41                                                   Forest Inventory and Analysis
# 42                                                 FWS National Wetlands Inventory
# 43                                                             USGS Gap Land Cover
# 44                                 Global Biodiversity Information Facility (GBIF)
# 45                                                 gNATSGO Soil Database - Rasters
# 46                                                  gNATSGO Soil Database - Tables
# 47                                                 GOES-R Cloud & Moisture Imagery
# 48                                                      GOES-R Lightning Detection
# 49                                                                       GPM IMERG
# 50                                                                         gridMET
# 51                                         HGB: Harmonized Global Biomass for 2010
# 52                                        HREA: High Resolution Electricity Access
# 53                                                         Biodiversity Intactness
# 54                                             Esri 10-Meter Land Cover (10-class)
# 55                                        10m Annual Land Use Land Cover (9-class)
# 56                                                        JRC Global Surface Water
# 57                                   HydroForecast - Kwando & Upper Zambezi Rivers
# 58                                                    Landsat Collection 2 Level-1
# 59                                                    Landsat Collection 2 Level-2
# 60                                            MoBI: Map of Biodiversity Importance
# 61                                          MODIS Surface Reflectance 8-Day (500m)
# 62                                          MODIS Surface Reflectance 8-Day (250m)
# 63                                                          MODIS Snow Cover Daily
# 64                                                          MODIS Snow Cover 8-day
# 65                                 MODIS Land Surface Temperature/Emissivity Daily
# 66                                 MODIS Land Surface Temperature/Emissivity 8-Day
# 67                                          MODIS Vegetation Indices 16-Day (500m)
# 68                                          MODIS Vegetation Indices 16-Day (250m)
# 69                                              MODIS Thermal Anomalies/Fire Daily
# 70                                              MODIS Thermal Anomalies/Fire 8-Day
# 71                                                MODIS Leaf Area Index/FPAR 8-Day
# 72                                                MODIS Leaf Area Index/FPAR 4-Day
# 73                                  MODIS Net Evapotranspiration Yearly Gap-Filled
# 74                                          MODIS Gross Primary Productivity 8-Day
# 75                               MODIS Gross Primary Productivity 8-Day Gap-Filled
# 76                                  MODIS Net Primary Production Yearly Gap-Filled
# 77                          MODIS Land Surface Temperature/3-Band Emissivity 8-Day
# 78                              MODIS Nadir BRDF-Adjusted Reflectance (NBAR) Daily
# 79                                                       MODIS Burned Area Monthly
# 80                                                   Microsoft Building Footprints
# 81                                        MTBS: Monitoring Trends in Burn Severity
# 82                                      NAIP: National Agriculture Imagery Program
# 83             Earth Exchange Global Daily Downscaled Projections (NEX-GDDP-CMIP6)
# 84                                                                NASADEM HGT v001
# 85                                            C-CAP Regional Land Cover and Change
# 86                                                   Global Ocean Heat Content CDR
# 87                                           Global Ocean Heat Content CDR NetCDFs
# 88                             Sea Surface Temperature - Optimum Interpolation CDR
# 89                                              Sea Surface Temperature - WHOI CDR
# 90                                      Sea Surface Temperature - WHOI CDR NetCDFs
# 91                       NOAA US Gridded Climate Normals (Cloud-Optimized GeoTIFF)
# 92                                        NOAA US Gridded Climate Normals (NetCDF)
# 93                                                 NOAA US Tabular Climate Normals
# 94                                                     NOAA MRMS QPE 1-Hour Pass 1
# 95                                                     NOAA MRMS QPE 1-Hour Pass 2
# 96                                                    NOAA MRMS QPE 24-Hour Pass 2
# 97                           Monthly NOAA U.S. Climate Gridded Dataset (NClimGrid)
# 98                                                            Land Cover of Canada
# 99                                                Planet-NICFI Basemaps (Analytic)
# 100                                                 Planet-NICFI Basemaps (Visual)
# 101                                 Sentinel 1 Level-1 Ground Range Detected (GRD)
# 102                             Sentinel 1 Radiometrically Terrain Corrected (RTC)
# 103                                                            Sentinel-2 Level-2A
# 104                                              Sentinel-3 Land (Full Resolution)
# 105                                             Sentinel-3 Water (Full Resolution)
# 106                                                Sentinel-3 Fire Radiative Power
# 107                                            Sentinel-3 Land Surface Temperature
# 108                                             Sentinel-3 Sea Surface Temperature
# 109                                                Sentinel-3 Land Radar Altimetry
# 110                                               Sentinel-3 Ocean Radar Altimetry
# 111                                                      Sentinel-3 Global Aerosol
# 112                                Sentinel-3 Land Surface Reflectance and Aerosol
# 113               Sentinel-3 10-Day Surface Reflectance and NDVI (SPOT VEGETATION)
# 114                Sentinel-3 1-Day Surface Reflectance and NDVI (SPOT VEGETATION)
# 115                     Sentinel-3 Top of Atmosphere Reflectance (SPOT VEGETATION)
# 116                                                            Sentinel-5P Level-2
# 117                                                                   TerraClimate
# 118                                                                      US Census
# 119                                               USDA Cropland Data Layers (CDLs)
# 120                                                USGS LCMAP CONUS Collection 1.3
# 121                                               USGS LCMAP Hawaii Collection 1.0

# %% [markdown]
# Note that there are a range of different datasets and models presented in this list. For this activity we are most interested in the Sentinel dataset listed at item number 103: **sentinel-2-l2a Sentinel-2 Level-2A**.
#
# We are also interested in the land cover assessment datasets. We should list all of these next to give a better idea of the global land cover model options available in DEP.
#
# To retrieve the list of global land cover models use:
# > *dep.list_global_land_cover()*

# %%
dep.list_global_land_cover()
# Out:
# only io-lulc-9-class and io-lulc are supported.
#                     0  \
# 0    chesapeake-lc-13
# 1     chesapeake-lc-7
# 2          drcog-lulc
# 3          esa-cci-lc
# 4   esa-cci-lc-netcdf
# 5      esa-worldcover
# 6                 gap
# 7             io-lulc
# 8     io-lulc-9-class
# 9          noaa-c-cap
# 10    nrcan-landcover
#
#                                                                           1
# 0                                          Chesapeake Land Cover (13-class)
# 1                                           Chesapeake Land Cover (7-class)
# 2                Denver Regional Council of Governments Land Use Land Cover
# 3   ESA Climate Change Initiative Land Cover Maps (Cloud Optimized GeoTIFF)
# 4                    ESA Climate Change Initiative Land Cover Maps (NetCDF)
# 5                                                            ESA WorldCover
# 6                                                       USGS Gap Land Cover
# 7                                       Esri 10-Meter Land Cover (10-class)
# 8                                  10m Annual Land Use Land Cover (9-class)
# 9                                      C-CAP Regional Land Cover and Change
# 10                                                     Land Cover of Canada

# %% [markdown]
# We will next list out the land cover models:
# > *dep.list_global_land_cover()*

# %% [markdown]
# Each of these examples of global, regional and national land cover models have been generated using a combination of local field data and machine learning approaches.
#
# However, none of them have been generated with lots of field data from Tonga. That's your job now!

# %% [markdown]
# <font color='blue'>Learning about the European Space Agency Sentinel 2 Satellite.</font>
# <font color = 'blue' ></font>

# %% [markdown]
# The main satellite data we will be using for this workshop is from the Copernicus Sentinel 2 satellite dataset as shown in figure s.2.a.
#
# <div><img src="https://github.com/digitalearthpacific/DigitalEarthPacific/blob/main/notebooks/DEP_LCAST/reference_materials/images/1B/Sentinel.1.jpg?raw=true" width="600"/></div>

# %% [markdown]
# Figure S.2.a. Provides an overview of Sentinel 2 satellite:
#
# The table in figure S.2.b. provides a list of the different bands or spectral wavelengths captured by the Sentinel 2 satellite. We will be using these for our analyses within the workshop.
#
# The bands are measured in wavelengths with unit measurements of nanometers. Visible light is measured in nanometers (nm). A nanometer is a unit of length equal to one billionth of a meter.
#
# These include optical bands we can see with the human eye:
# - (B2) Blue = 458-523 nm
# - (B3) Green = 543-578 nm
# - (B4) Red = 650-680 nm
#
# And infrared bands that cannot be detected by the human eye:
# - (B8) Near Infrared or NIR = 785-900 nm
# - (B11) Shortwave Infrared 1 or SWIR 1 = 1565-1655 nm
#
# For the full list see Figure S.2.b.
#
# <div><img src="https://github.com/digitalearthpacific/DigitalEarthPacific/blob/main/notebooks/DEP_LCAST/reference_materials/images/1B/Sentinel.2.png?raw=true="600" width="580"/></div>

# %% [markdown]
# Figure S.2.b. Table list of spectral bands captured by sensors on the Sentinel 2 satellite
#
# A visualisation of these bands from the table in S.2.b. is visualised as a spectrum in figure S.2.c.
#
#
#
#
#
# <div><img src="https://github.com/digitalearthpacific/DigitalEarthPacific/blob/main/notebooks/DEP_LCAST/reference_materials/images/1B/Sentinel.3.jpg?raw=true="600" width="580"/></div>

# %% [markdown]
# Figure S.2.c. The spectrum of different wavelengths visualised:

# %% [markdown]
# Run this code to learn more about the data stored in DEP for using Sentinel 2:
#
# > *dep.list_data_bands("sentinel-2-l2a")*

# %%
dep.list_data_bands("sentinel-2-l2a")
# Out:
#    name                                         description   gsd common_name  \
# 0   AOT                           aerosol optical thickness   NaN         NaN
# 1   B01                                     coastal aerosol  60.0     coastal
# 2   B02                                        visible blue  10.0        blue
# 3   B03                                       visible green  10.0       green
# 4   B04                                         visible red  10.0         red
# 5   B05                  vegetation classification red edge  20.0     rededge
# 6   B06                  vegetation classification red edge  20.0     rededge
# 7   B07                  vegetation classification red edge  20.0     rededge
# 8   B08                                       near infrared  10.0         nir
# 9   B8A                  vegetation classification red edge  20.0     rededge
# 10  B09                                         water vapor  60.0         NaN
# 11  B11  short-wave infrared, snow/ice/cloud classification  20.0      swir16
# 12  B12  short-wave infrared, snow/ice/cloud classification  20.0      swir22
#
#     center_wavelength  full_width_half_max
# 0                 NaN                  NaN
# 1               0.443                0.027
# 2               0.490                0.098
# 3               0.560                0.045
# 4               0.665                0.038
# 5               0.704                0.019
# 6               0.740                0.018
# 7               0.783                0.028
# 8               0.842                0.145
# 9               0.865                0.033
# 10              0.945                0.026
# 11              1.610                0.143
# 12              2.190                0.242

# %% [markdown]
# <font color='blue'>Review Activity for Notebook 1B) - selecting and exploring your study area.</font>
# <font color = 'blue' ></font>
#
# You have been asked to generate a map with the boundaries for Tongatapu. Using the workflow provided above complete the following steps:
#
# 1. List the boundary types for Tonga

# %% [markdown]
# 2. List the country boundary types for Island Groups in Tonga

# %% [markdown]
# 3. Get the boundary for Tongatapu

# %% [markdown]
# 4. Explore the map for Tongatapu

# %% [markdown]
# Ensure your notebooks end with `dep.cleanup()` to ensure all resources are released.

# %%
dep.cleanup()
